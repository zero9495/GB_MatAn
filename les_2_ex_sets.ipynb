# %%
set_a = {1,2,3,4}
set_b = {3,4,5,6}

print('union: {}'.format(set_a.union(set_b)))
print('intersection: {}'.format(set_a.intersection(set_b)))
print('difference: {}'.format(set_a.difference(set_b)))
print('symmetric_difference: {}'.format(set_a.symmetric_difference(set_b)))
# Out:
# union: {1, 2, 3, 4, 5, 6}
# intersection: {3, 4}
# difference: {1, 2}
# symmetric_difference: {1, 2, 5, 6}
